# %% [markdown]
# ## **Generic Medicine Recommender**

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# **Loading the Dataset**

# %%
medicines = pd.read_csv('gen_normal.csv')

# %%
medicines = pd.read_csv('medicine.csv')

# %%
medicines.head()
# Out:
#    Sr. No.                                          Drug_Name  \
# 0        1  Aceclofenac 100mg and Paracetamol 325 mg  Tabl...
# 1        2                  Aceclofenac Tablets IP 100mg 10's
# 2        3  Acetaminophen 325 + Tramadol Hydrochloride 37....
# 3        4                     ASPIRIN Tablets IP 150 mg 14's
# 4        5  DICLOFENAC 50 mg+ PARACETAMOL 325 mg+\nCHLORZO...
#
#                           Therapeutic Category  \
# 0  Analgesic & Antipyretic / Muscle\nrelaxants
# 1  Analgesic & Antipyretic / Muscle\nrelaxants
# 2  Analgesic & Antipyretic / Muscle\nrelaxants
# 3  Analgesic & Antipyretic / Muscle\nrelaxants
# 4   Analgesic & Antipyretic / Muscle relaxants
#
#                                          Description
# 0  Combines an NSAID and a pain reliever to reduc...
# 1  Provides relief from pain and inflammation as ...
# 2  Combines a pain reliever and a moderate opioid...
# 3  Used to relieve pain, reduce inflammation, and...
# ...

# %%
medicines.shape
# Out:
# (10419, 4)

# %% [markdown]
# **Preprocessing the Dataset**

# %%
medicines.isnull().sum()
# Out:
# Sr. No.                 0
# Drug_Name               0
# Therapeutic Category    0
# Description             0
# dtype: int64

# %%
medicines.dropna(inplace=True)

# %%
medicines.duplicated().sum()
# Out:
# 0

# %%
medicines['Description']
# Out:
# 0        Combines an NSAID and a pain reliever to reduc...
# 1        Provides relief from pain and inflammation as ...
# 2        Combines a pain reliever and a moderate opioid...
# 3        Used to relieve pain, reduce inflammation, and...
# 4        Relieves pain and inflammation with an added m...
#                                ...
# 10414                              used for treating warts
# 10415                        used to soften the skin cells
# 10416                                       used for scars
# 10417                                      used for wounds
# 10418    used to treat and remove raised warts (usually...
# Name: Description, Length: 10419, dtype: object

# %% [markdown]
# **Feature Engineering**

# %%
medicines['Description'].apply(lambda x:x.split())
# Out:
# 0        [Combines, an, NSAID, and, a, pain, reliever, ...
# 1        [Provides, relief, from, pain, and, inflammati...
# 2        [Combines, a, pain, reliever, and, a, moderate...
# 3        [Used, to, relieve, pain,, reduce, inflammatio...
# 4        [Relieves, pain, and, inflammation, with, an, ...
#                                ...
# 10414                         [used, for, treating, warts]
# 10415                 [used, to, soften, the, skin, cells]
# 10416                                   [used, for, scars]
# 10417                                  [used, for, wounds]
# 10418    [used, to, treat, and, remove, raised, warts, ...
# Name: Description, Length: 10419, dtype: object

# %%
medicines['Therapeutic Category'] = medicines['Therapeutic Category'].apply(lambda x:x.split())
medicines['Description'] = medicines['Description'].apply(lambda x:x.split())

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['tags'] = medicines['Description'] + medicines['Therapeutic Category']

# %%
new_df = medicines[['Sr. No.','Drug_Name','tags']]

# %%
new_df
# Out:
#        Sr. No.                                          Drug_Name  \
# 0            1  Aceclofenac 100mg and Paracetamol 325 mg  Tabl...
# 1            2                  Aceclofenac Tablets IP 100mg 10's
# 2            3  Acetaminophen 325 + Tramadol Hydrochloride 37....
# 3            4                     ASPIRIN Tablets IP 150 mg 14's
# 4            5  DICLOFENAC 50 mg+ PARACETAMOL 325 mg+\nCHLORZO...
# ...        ...                                                ...
# 10414    10415                                T Muce Ointment 5gm
# 10415    10416  Wokadine 10% Solution 100mlWokadine Solution 5...
# 10416    10417                               Wokadine M Onit 10gm
# 10417    10418                           Wound Fix Solution 100ml
# 10418    10419                              Wounsol Ointment 15gm
#
#                                                     tags
# 0      [Combines, an, NSAID, and, a, pain, reliever, ...
# 1      [Provides, relief, from, pain, and, inflammati...
# ...

# %%
new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# 0        Combines an NSAID and a pain reliever to reduc...
# 1        Provides relief from pain and inflammation as ...
# 2        Combines a pain reliever and a moderate opioid...
# 3        Used to relieve pain, reduce inflammation, and...
# 4        Relieves pain and inflammation with an added m...
#                                ...
# 10414                        used for treating warts Wound
# 10415                  used to soften the skin cells Wound
# 10416                                 used for scars Wound
# 10417                                used for wounds Wound
# 10418    used to treat and remove raised warts (usually...
# Name: tags, Length: 10419, dtype: object

# %%
new_df
# Out:
#        Sr. No.                                          Drug_Name  \
# 0            1  Aceclofenac 100mg and Paracetamol 325 mg  Tabl...
# 1            2                  Aceclofenac Tablets IP 100mg 10's
# 2            3  Acetaminophen 325 + Tramadol Hydrochloride 37....
# 3            4                     ASPIRIN Tablets IP 150 mg 14's
# 4            5  DICLOFENAC 50 mg+ PARACETAMOL 325 mg+\nCHLORZO...
# ...        ...                                                ...
# 10414    10415                                T Muce Ointment 5gm
# 10415    10416  Wokadine 10% Solution 100mlWokadine Solution 5...
# 10416    10417                               Wokadine M Onit 10gm
# 10417    10418                           Wound Fix Solution 100ml
# 10418    10419                              Wounsol Ointment 15gm
#
#                                                     tags
# 0      [Combines, an, NSAID, and, a, pain, reliever, ...
# 1      [Provides, relief, from, pain, and, inflammati...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-167-ad44e9ca1347>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df
# Out:
#        Sr. No.                                          Drug_Name  \
# 0            1  Aceclofenac 100mg and Paracetamol 325 mg  Tabl...
# 1            2                  Aceclofenac Tablets IP 100mg 10's
# 2            3  Acetaminophen 325 + Tramadol Hydrochloride 37....
# 3            4                     ASPIRIN Tablets IP 150 mg 14's
# 4            5  DICLOFENAC 50 mg+ PARACETAMOL 325 mg+\nCHLORZO...
# ...        ...                                                ...
# 10414    10415                                T Muce Ointment 5gm
# 10415    10416  Wokadine 10% Solution 100mlWokadine Solution 5...
# 10416    10417                               Wokadine M Onit 10gm
# 10417    10418                           Wound Fix Solution 100ml
# 10418    10419                              Wounsol Ointment 15gm
#
#                                                     tags
# 0      Combines an NSAID and a pain reliever to reduc...
# 1      Provides relief from pain and inflammation as ...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# <ipython-input-169-8b60b591a07f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df
# Out:
#        Sr. No.                                          Drug_Name  \
# 0            1  Aceclofenac 100mg and Paracetamol 325 mg  Tabl...
# 1            2                  Aceclofenac Tablets IP 100mg 10's
# 2            3  Acetaminophen 325 + Tramadol Hydrochloride 37....
# 3            4                     ASPIRIN Tablets IP 150 mg 14's
# 4            5  DICLOFENAC 50 mg+ PARACETAMOL 325 mg+\nCHLORZO...
# ...        ...                                                ...
# 10414    10415                                T Muce Ointment 5gm
# 10415    10416  Wokadine 10% Solution 100mlWokadine Solution 5...
# 10416    10417                               Wokadine M Onit 10gm
# 10417    10418                           Wound Fix Solution 100ml
# 10418    10419                              Wounsol Ointment 15gm
#
#                                                     tags
# 0      combines an nsaid and a pain reliever to reduc...
# 1      provides relief from pain and inflammation as ...
# ...

# %%
# !pip install nltk
# Out:
# ...
# ERROR: Operation cancelled by user

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
# !pip install -U scikit-learn scipy matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 47.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 MB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 97.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english',max_features=5000)

# %%
def stem(text):
  y = []

  for i in text.split():
    y.append(ps.stem(i))

  return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# <ipython-input-176-be18a4346d89>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
cv.fit_transform(new_df['tags']).toarray().shape
# Out:
# (10419, 1332)

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
cv.get_feature_names_out()
# Out:
# array(['025', '10', '12', ..., 'zollinger', 'zost', 'œpancreat'],
#       dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# **Testing**

# %%
# import pandas as pd
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# from scipy.sparse import csr_matrix, save_npz
# import numpy as np
# from sklearn.preprocessing import normalize

# # Initialize the CountVectorizer with stop words and max features
# cv = CountVectorizer(stop_words='english', max_features=5000)

# # Transform text data into a sparse matrix
# X = cv.fit_transform(new_df['tags'])

# # Normalize the vectors
# X = normalize(X)

# # Chunk size for processing
# chunk_size = 1000

# # Get the number of samples
# n_samples = X.shape[0]

# # Compute similarities in chunks
# for start in range(0, n_samples, chunk_size):
#     end = min(start + chunk_size, n_samples)

#     # Slice the matrix
#     X_chunk = X[start:end]

#     # Compute cosine similarity between the chunk and the entire matrix
#     cosine_sim_chunk = cosine_similarity(X_chunk, X)

#     # Optionally, you can save or process each chunk here
#     # Example: save each chunk to a file (for demonstration purposes)
#     save_npz(f'cosine_similarity_chunk_{start}_{end}.npz', csr_matrix(cosine_sim_chunk))

#     print(f"Processed chunk {start} to {end}")

# print("Chunk-based cosine similarity computation complete.")
# Out:
# Processed chunk 0 to 699
# Chunk-based cosine similarity computation complete.

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.64715023, 0.74124932, ..., 0.        , 0.        ,
#         0.        ],
#        [0.64715023, 1.        , 0.53452248, ..., 0.        , 0.        ,
#         0.        ],
#        [0.74124932, 0.53452248, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 1.        , 0.77459667,
#         0.2981424 ],
#        [0.        , 0.        , 0.        , ..., 0.77459667, 1.        ,
#         0.34641016],
#        [0.        , 0.        , 0.        , ..., 0.2981424 , 0.34641016,
#         1.        ]])

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[1]
# Out:
# array([0.64715023, 1.        , 0.53452248, ..., 0.        , 0.        ,
#        0.        ])

# %% [markdown]
# **Testing 2**

# %%
from scipy.sparse import csr_matrix, save_npz, load_npz

# Define the recommendation function
def recommend(medicine_name):
    # Find the index of the medicine
    try:
        medicine_index = new_df[new_df['name'] == medicine_name].index[0]
    except IndexError:
        print(f"Medicine '{medicine_name}' not found in the DataFrame.")
        return

    # Load all chunks to get the full similarity matrix
    full_similarity = np.zeros((n_samples, n_samples))
    for start in range(0, n_samples, chunk_size):
        end = min(start + chunk_size, n_samples)
        chunk = load_npz(f'cosine_similarity_chunk_{start}_{end}.npz').toarray()
        full_similarity[start:end] = chunk

    # Get the similarity scores for the specified medicine
    distances = full_similarity[medicine_index]

    # Get the indices of the most similar medicines
    medicines_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6]

    # Print the names of the recommended medicines
    print(f"Recommended medicines for '{medicine_name}':")
    for i in medicines_list:
        print(new_df.iloc[i[0]].name)

# %%
# Example usage
recommend('Augmentin 625 Duo Tablet')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-47-5cb4a6707798> in <cell line: 2>()
#       1 # Example usage
# ----> 2 recommend('Augmentin 625 Duo Tablet')
#
# <ipython-input-46-37ca4afbeb63> in recommend(medicine_name)
#      14     for start in range(0, n_samples, chunk_size):
#      15         end = min(start + chunk_size, n_samples)
# ---> 16         chunk = load_npz(f'cosine_similarity_chunk_{start}_{end}.npz').toarray()
#      17         full_similarity[start:end] = chunk
#      18
#
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_matrix_io.py in load_npz(file)
#     132     >>> sparse_array = sp.sparse.csr_array(tmp)
#     133     """
# --> 134     with np.load(file, **PICKLE_KWARGS) as loaded:
#     135         sparse_format = loaded.get('format')
#     136         if sparse_format is None:
#
# ...

# %%
def recommend(medicine):
    medicine_index = new_df[new_df['Drug_Name'] == medicine].index[0]
    distances = similarity[medicine_index]
    medicines_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]

    for i in medicines_list:
        print(new_df.iloc[i[0]].Drug_Name)

# %%
recommend("Silverex Heal Gel 15gm")
# Out:
# Betadine Antiseptic Ointment 20gm
# Burnheal Dusting Powder 10gm
# Cetrilak Strong Solution 100ml
# Drez 5Cm Tulle
# Hexilak Gel 20gmHexilak Gel 10gm

# %% [markdown]
# **Storing the Data in .pkl file**

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('medicine_dict.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
